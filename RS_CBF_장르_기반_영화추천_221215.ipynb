# %% [markdown]
# <a href="https://colab.research.google.com/github/bongkyunSON/Deep_Leaning/blob/main/RS_CBF_%EC%9E%A5%EB%A5%B4_%EA%B8%B0%EB%B0%98_%EC%98%81%ED%99%94%EC%B6%94%EC%B2%9C_221215.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/Users/aiden/Dropbox/Mac/Desktop/code/4.CBF'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd  # 데이터 분석을 위한 라이브러리
import numpy as np   # 넘파이 : 숫자 계산

# 워닝(버전, 업데이트 문제, 에러는 아님) 코드는 실행되는데 정보. 귀찮을 때 워닝 끄기
import warnings
warnings.filterwarnings('ignore')

# %%
movies_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DeepLearning/RS/data/tmdb_5000_movies.csv')

# %%
print(movies_df.shape)  # 행, 열 개수 파악
movies_df.head()
# Out:
# (4803, 20)
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# 필요한 컬럼만 추출
movies_df = movies_df[['id','title','genres','vote_average','vote_count','popularity','keywords','overview']]
movies_df.head(3)
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
#
#                                               genres  vote_average  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...           7.2
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...           6.9
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...           6.3
#
#    vote_count  popularity                                           keywords  \
# 0       11800  150.437577  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1        4500  139.082615  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2        4466  107.376788  [{"id": 470, "name": "spy"}, {"id": 818, "name...
#
#                                             overview
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# ...

# %%
print(type(movies_df['genres'][0]))
movies_df['genres'][0]
# Out:
# <class 'str'>
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
from ast import literal_eval

print(type(literal_eval(movies_df['genres'][0])))
literal_eval(movies_df['genres'][0])
# Out:
# <class 'list'>
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
type(movies_df['genres'][0])
# str 타입인 것을 확인할 수 있다.
# Out:
# str

# %% [markdown]
# ### genres, keywords 칼럼들의 str형태를 list형태로 바꿔주기

# %%
movies_df['genres']
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4798    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                   []
# 4802                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4803, dtype: object

# %%
from ast import literal_eval  # 문자열 파싱 라이브러리
movies_df['genres'] = movies_df['genres'].apply(literal_eval)
movies_df['keywords'] = movies_df['keywords'].apply(literal_eval)

# %%
print(movies_df['genres'][0])
# Out:
# [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 878, 'name': 'Science Fiction'}]

# %%
movies_df['genres'][0][0]['name']
# Out:
# 'Action'

# %%
type(movies_df['genres'][0])
# str타입에서 list타입으로 바뀐 것을 확인할 수 있다.
# Out:
# list

# %% [markdown]
# ### list 내 여러개 딕셔너리의 name키에 해당하는 값들을 리스트로 변환

# %%
movies_df['genres']
# Out:
# 0       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1       [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3       [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#                               ...
# 4798    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 4799    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 4800    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4801                                                   []
# 4802                  [{'id': 99, 'name': 'Documentary'}]
# Name: genres, Length: 4803, dtype: object

# %%
# avatar
movies_df['genres'][0][0]['name']
# Out:
# 'Action'

# %%
# df['컬럼'].apply(lambda 함수) : df 컬럼(ex.장르)의 각각의 값들에 대해서 함수(lambda 함수)를 적용해라
# apply, map 
# 람다 함수
# list comprehension
# apply lambda
# 리스트 컴프리헨션(list comprehension)
movies_df['genres'] = movies_df['genres'].apply(lambda x : [ y['name'] for y in x ])
movies_df['keywords'] = movies_df['keywords'].apply(lambda x : [ y['name'] for y in x])

# %%
movies_df[['genres']][0:3]
# Out:
#                                           genres
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]

# %%
movies_df[movies_df['genres']=='[]']
# Out:
# Empty DataFrame
# Columns: [id, title, genres, vote_average, vote_count, popularity, keywords, overview]
# Index: []

# %% [markdown]
# ## -> 데이터 전처리 끝

# %%
movies_df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                              genres  vote_average  vote_count  \
# 0     [Action, Adventure, Fantasy, Science Fiction]           7.2       11800
# 1                      [Adventure, Fantasy, Action]           6.9        4500
# ...

# %% [markdown]
# ## 장르 컨텐츠 유사도 측정

# %% [raw]
# 문서(ex. 영화의 장르들) 유사도를 측정하는 방법들
# 1. 거리 기반
# - 유클리디안 거리
#
# 2. 각도 기반
# - 코사인 유사도

# %% [raw]
# @ 장르 CBF 추천 : 장르를 피처 벡터화한 후 행렬 데이터 값을 코사인 유사도(0~1)로 계산하기
#
# <프로세스>
# 1. 장르 피처 벡터화 : 문자열로 변환된 genres 칼럼을 Count 기반으로 피처 벡터화 변환
# 2. 코사인 유사도 계산 : genres 문자열을 피처 벡터화한 행렬로 변환한 데이터 세트를 코사인 유사도로 비교
# 3. 평점으로 계산 : 장르 유사도가 높은 영화 중 평점이 높은 순으로 영화 추천

# %% [markdown]
# ### 그 전에, CountVectorizer 소개

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# 참고 : CountVectorizer에 대하여
# CountVectorizer는 다음 세가지를 수행한다.
# 1. 문서를 토큰 리스트로 변환한다.
# 2. 각 문서에서 토큰의 출현 빈도를 센다.
# 3. 각 문서를 BOW(Bag of Words) 인코딩 벡터로 변환한다.

from sklearn.feature_extraction.text import CountVectorizer
corpus = [
    'This is the first document.',
    'This is the second second document.',
    'And the third one.',
    'Is this the first document?',
    'The last document?',
]

# 토큰 별 인덱스 사전을 만들어준다.
vect = CountVectorizer()
vect.fit(corpus)

# RS(추천시스템), nlp(자연어처리), cv(컴퓨터비젼)
# 단어 사전 -> 데이터 분석, 자연어처리
vect.vocabulary_
# Out:
# {'this': 9,
#  'is': 3,
#  'the': 7,
#  'first': 2,
#  'document': 1,
#  'second': 6,
#  'and': 0,
#  'third': 8,
#  'one': 5,
#  'last': 4}

# %%
movies_df['genres']
# Out:
# 0       [Action, Adventure, Fantasy, Science Fiction]
# 1                        [Adventure, Fantasy, Action]
# 2                          [Action, Adventure, Crime]
# 3                    [Action, Crime, Drama, Thriller]
# 4                [Action, Adventure, Science Fiction]
#                             ...
# 4798                        [Action, Crime, Thriller]
# 4799                                [Comedy, Romance]
# 4800               [Comedy, Drama, Romance, TV Movie]
# 4801                                               []
# 4802                                    [Documentary]
# Name: genres, Length: 4803, dtype: object

# %%
# CountVectorizer를 적용하기 위해 공백문자로 word 단위가 구분되는 문자열로 변환. 
movies_df['genres_literal'] = movies_df['genres'].apply(lambda x : (' ').join(x))
movies_df['genres_literal']
# Out:
# 0       Action Adventure Fantasy Science Fiction
# 1                       Adventure Fantasy Action
# 2                         Action Adventure Crime
# 3                    Action Crime Drama Thriller
# 4               Action Adventure Science Fiction
#                           ...
# 4798                       Action Crime Thriller
# 4799                              Comedy Romance
# 4800               Comedy Drama Romance TV Movie
# 4801
# 4802                                 Documentary
# Name: genres_literal, Length: 4803, dtype: object

# %%
movies_df['genres_literal'][0]
# Out:
# 'Action Adventure Fantasy Science Fiction'

# %%
# CountVectorizer로 학습시켰더니 4803개 영화에 대한 276개 장르의 '장르 매트릭스'가 생성되었다. ngram_range=(1, 2)

count_vect = CountVectorizer(min_df=0, ngram_range=(1, 2))  # min_df: 단어장에 들어갈 최소빈도 ngram_range는 보통 1,2를 많이한다
genre_mat = count_vect.fit_transform(movies_df['genres_literal'])

print(genre_mat.shape)
print(genre_mat)
# 영화 별 장르 인덱스 사전을 만들어준다
# Out:
# (4803, 276)
#   (0, 0)	1
#   (0, 16)	1
#   (0, 124)	1
#   (0, 232)	1
#   (0, 138)	1
#   (0, 1)	1
#   (0, 24)	1
#   (0, 135)	1
#   (0, 233)	1
#   (1, 0)	1
#   (1, 16)	1
#   (1, 124)	1
#   (1, 24)	1
#   (1, 125)	1
#   (2, 0)	1
#   (2, 16)	1
#   (2, 1)	1
#   (2, 64)	1
#   (2, 20)	1
#   (3, 0)	1
#   (3, 64)	1
#   (3, 90)	1
#   (3, 234)	1
#   (3, 4)	1
#   (3, 68)	1
#   :	:
#   (4796, 90)	1
#   (4796, 234)	1
#   (4796, 106)	1
#   (4796, 144)	1
#   (4797, 234)	1
#   (4797, 153)	1
#   (4797, 157)	1
#   (4798, 0)	1
#   (4798, 64)	1
#   (4798, 234)	1
#   (4798, 4)	1
#   (4798, 78)	1
#   (4799, 44)	1
#   (4799, 214)	1
#   (4799, 58)	1
#   (4800, 90)	1
#   (4800, 44)	1
#   (4800, 214)	1
#   (4800, 104)	1
#   (4800, 50)	1
#   (4800, 250)	1
#   (4800, 182)	1
#   (4800, 251)	1
#   (4800, 229)	1
#   (4802, 80)	1

# %% [raw]
# * ngram 인자값 조절
#
# 1 <= ngram <= 1 일 때 장르 피쳐 5개 : Action, Adventure, Fantasy, Science, Fiction
#
# 2 <= ngram <= 2 일 때 장르 피쳐 4개 : Action Adventure, Adventure Fantasy, Fantasy Science, Science Fiction
#
# 1 <= ngram <= 2 일 때 장르 피쳐 9개 : Action, Adventure, Fantasy, Science, Fiction, Action Adventure, Adventure Fantasy, Fantasy Science, Science Fiction

# %%
# CountVectorizer로 학습시켰더니 4803개 영화에 대한 22개 장르의 '장르 매트릭스'가 생성되었다. ngram_range=(1, 1)
count_vect2 = CountVectorizer(min_df=1, ngram_range=(1, 1))  # min_df: 단어장에 들어갈 최소빈도
genre_mat2 = count_vect2.fit_transform(movies_df['genres_literal'])
print(genre_mat2.shape)
print(genre_mat2)
# Out:
# (4803, 22)
#   (0, 0)	1
#   (0, 1)	1
#   (0, 8)	1
#   (0, 17)	1
#   (0, 9)	1
#   (1, 0)	1
#   (1, 1)	1
#   (1, 8)	1
#   (2, 0)	1
#   (2, 1)	1
#   (2, 4)	1
#   (3, 0)	1
#   (3, 4)	1
#   (3, 6)	1
#   (3, 18)	1
#   (4, 0)	1
#   (4, 1)	1
#   (4, 17)	1
#   (4, 9)	1
#   (5, 0)	1
#   (5, 1)	1
#   (5, 8)	1
#   (6, 2)	1
#   (6, 7)	1
#   (7, 0)	1
#   :	:
#   (4792, 18)	1
#   (4792, 12)	1
#   (4792, 15)	1
#   (4793, 6)	1
#   (4794, 18)	1
#   (4794, 3)	1
#   (4794, 12)	1
#   (4795, 6)	1
#   (4796, 17)	1
#   (4796, 9)	1
#   (4796, 6)	1
#   (4796, 18)	1
#   (4797, 18)	1
#   (4797, 10)	1
#   (4798, 0)	1
#   (4798, 4)	1
#   (4798, 18)	1
#   (4799, 3)	1
#   (4799, 16)	1
#   (4800, 6)	1
#   (4800, 3)	1
#   (4800, 16)	1
#   (4800, 19)	1
#   (4800, 13)	1
#   (4802, 5)	1

# %% [markdown]
# ### 코사인 유사도(cosine_similarity)를 이용해서 영화별 유사도 계산

# %%
# 코사인 유사도에 의해 4803개 영화 각각 유사한 영화들이 계산됨
from sklearn.metrics.pairwise import cosine_similarity
genre_sim = cosine_similarity(genre_mat, genre_mat)

print(genre_sim.shape)
print(genre_sim[:10])
# Out:
# (4803, 4803)
# [[1.         0.59628479 0.4472136  ... 0.         0.         0.        ]
#  [0.59628479 1.         0.4        ... 0.         0.         0.        ]
#  [0.4472136  0.4        1.         ... 0.         0.         0.        ]
#  ...
#  [0.75592895 0.3380617  0.50709255 ... 0.         0.         0.        ]
#  [0.4472136  0.6        0.2        ... 0.         0.         0.        ]
#  [0.74535599 0.8        0.6        ... 0.         0.         0.        ]]

# %%
for i in range(0, 5):
    print(genre_sim[i][:5])
# Out:
# [1.         0.59628479 0.4472136  0.12598816 0.75592895]
# [0.59628479 1.         0.4        0.16903085 0.3380617 ]
# [0.4472136  0.4        1.         0.3380617  0.50709255]
# [0.12598816 0.16903085 0.3380617  1.         0.14285714]
# [0.75592895 0.3380617  0.50709255 0.14285714 1.        ]

# %% [raw]
# - 값 정렬 함수, 인덱스 정렬 함수
#
# - sort 함수 : 값 정렬
#
# - argsort 함수 : 값에 따른 인덱스 정렬

# %%
# 자료를 정렬하는 것이 아니라 순서만 알고 싶다면 argsort
# 유사도가 높은 영화를 앞에서부터 순서대로 보여줌

# 0번째 영화의 경우 유사도 순서 : 0번 영화, 3494번, 813번, ..., 2401번 영화 순서
genre_sim_sorted_ind = genre_sim.argsort()[:, ::-1]   # ::-1 : 역순으로 정렬
print(genre_sim_sorted_ind[:5])
# Out:
# [[   0 3494  813 ... 3038 3037 2401]
#  [ 262    1  129 ... 3069 3067 2401]
#  [   2 1740 1542 ... 3000 2999 2401]
#  [2195 1850 3316 ...  887 2544 4802]
#  [ 102 2995   56 ... 3046 3045 2401]]

# %%
genre_sim_sorted_ind
# Out:
# array([[   0, 3494,  813, ..., 3038, 3037, 2401],
#        [ 262,    1,  129, ..., 3069, 3067, 2401],
#        [   2, 1740, 1542, ..., 3000, 2999, 2401],
#        ...,
#        [4800, 3809, 1895, ..., 2229, 2230,    0],
#        [4802, 1594, 1596, ..., 3204, 3205,    0],
#        [4802, 4710, 4521, ..., 3140, 3141,    0]])

# %% [markdown]
# ## 추천 ver1. 장르 코사인 유사도에 의해 영화를 추천하는 함수

# %% [markdown]
# ### 함수 분석

# %%
# 인자로 입력된 movies_df DataFrame에서 'title' 컬럼이 입력된 title_name 값인 DataFrame추출
title_movie = movies_df[movies_df['title'] == 'Avatar']
title_movie
# Out:
#       id   title                                         genres  vote_average  \
# 0  19995  Avatar  [Action, Adventure, Fantasy, Science Fiction]           7.2
#
#    vote_count  popularity                                           keywords  \
# 0       11800  150.437577  [culture clash, future, space war, space colon...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                              genres_literal
# 0  Action Adventure Fantasy Science Fiction

# %%
# (참고)평점이 7점 이상인 영화 찾기
vote7_movie = movies_df.loc[movies_df['vote_average'] > 7]
vote7_movie
# Out:
#           id                                   title  \
# 0      19995                                  Avatar
# 3      49026                   The Dark Knight Rises
# 6      38757                                 Tangled
# 7      99861                 Avengers: Age of Ultron
# 8        767  Harry Potter and the Half-Blood Prince
# ...      ...                                     ...
# 4755  322745                                Counting
# 4766   13963                          The Last Waltz
# 4773    2292                                  Clerks
# 4792   36095                                    Cure
# 4797   67238                                  Cavite
#
#                                              genres  vote_average  vote_count  \
# 0     [Action, Adventure, Fantasy, Science Fiction]           7.2       11800
# 3                  [Action, Crime, Drama, Thriller]           7.6        9106
# 6                               [Animation, Family]           7.4        3330
# ...

# %%
# title_named을 가진 DataFrame의 index 객체를 ndarray로 반환하고 
# sorted_ind 인자로 입력된 genre_sim_sorted_ind 객체에서 유사도 순으로 top_n 개의 index 추출
title_index = title_movie.index.values
title_index
# Out:
# array([0])

# %%
similar_indexes = genre_sim_sorted_ind[title_index, :10]
similar_indexes
# Out:
# array([[   0, 3494,  813,  870,   46,   14, 1296, 1652,  419,  420]])

# %%
# 추출된 top_n index들 출력. top_n index는 2차원 데이터 임.
# dataframe에서 index로 사용하기 위해서 2차원 array를 1차원 array로 변경
similar_indexes = similar_indexes.reshape(-1)
print(similar_indexes)
# Out:
# [   0 3494  813  870   46   14 1296 1652  419  420]

# %%
# 아바타와 가장 장르의 코사인 유사도가 높은 영화 10개
movies_df.iloc[similar_indexes]
# Out:
#           id                                      title  \
# 0      19995                                     Avatar
# 3494   27549  Beastmaster 2: Through the Portal of Time
# 813     1924                                   Superman
# 870     8536                                Superman II
# 46    127585                 X-Men: Days of Future Past
# 14     49521                               Man of Steel
# 1296    9531                               Superman III
# 1652   14164                       Dragonball Evolution
# 419     8247                                     Jumper
# 420    11253                Hellboy II: The Golden Army
#
#                                                  genres  vote_average  \
# 0         [Action, Adventure, Fantasy, Science Fiction]           7.2
# 3494      [Action, Adventure, Fantasy, Science Fiction]           4.6
# 813       [Action, Adventure, Fantasy, Science Fiction]           6.9
# ...

# %% [markdown]
# ### 실제 함수

# %%
def find_sim_movie_ver1(df, sorted_ind, title_name, top_n=10):
    
    # 인자로 입력된 movies_df DataFrame에서 'title' 컬럼이 입력된 title_name 값인 DataFrame추출
    title_movie = df[df['title'] == title_name]
    
    # title_named을 가진 DataFrame의 index 객체를 ndarray로 반환하고 
    # sorted_ind 인자로 입력된 genre_sim_sorted_ind 객체에서 유사도 순으로 top_n 개의 index 추출
    title_index = title_movie.index.values
    similar_indexes = sorted_ind[title_index, :(top_n)]
    
    # 추출된 top_n index들 출력. top_n index는 2차원 데이터 임.
    # dataframe에서 index로 사용하기 위해서 1차원 array로 변경
    print(similar_indexes)    
    # 2차원 데이터를 1차원으로 변환
    similar_indexes = similar_indexes.reshape(-1)   # 2차원 -> 1차원으로 바꿔준다  e.g. [[2, 3]] -> [2, 3, 6, 12, ...., 193]
    
    return df.iloc[similar_indexes]

# %% [markdown]
# ### 영화 Gotfather와 장르가 유사한 영화 10개 추천

# %%
similar_movies = find_sim_movie_ver1(movies_df, genre_sim_sorted_ind, 'The Godfather', 10)

similar_movies[['title', 'vote_average', 'genres', 'vote_count']]
# 문제 ; 평점 기반으로 추천하고자 하는데, vote_count가 낮은 영화는 제외하고 싶음
# Out:
# [[2731 1243 3636 1946 2640 4065 1847 4217  883 3866]]
#                                                title  vote_average  \
# 2731                          The Godfather: Part II           8.3
# 1243                                    Mean Streets           7.2
# 3636                                   Light Sleeper           5.7
# 1946  The Bad Lieutenant: Port of Call - New Orleans           6.0
# 2640         Things to Do in Denver When You're Dead           6.7
# 4065                                      Mi America           0.0
# 1847                                      GoodFellas           8.2
# 4217                                            Kids           6.8
# 883                              Catch Me If You Can           7.7
# 3866                                     City of God           8.1
#
#               genres  vote_count
# 2731  [Drama, Crime]        3338
# 1243  [Drama, Crime]         345
# 3636  [Drama, Crime]          15
# 1946  [Drama, Crime]         326
# ...

# %%
# 평점 기준으로 정렬(sort_values)해보니 평가횟수(vote_count)가 낮은 것들도 포함됨. 평가횟수 반영한 평점(가중 평점)이 필요함
movies_df[['title','vote_average','vote_count']].sort_values('vote_average', ascending=False)[:10]
# Out:
#                          title  vote_average  vote_count
# 3519          Stiff Upper Lips          10.0           1
# 4247     Me You and Five Bucks          10.0           2
# 4045     Dancer, Texas Pop. 81          10.0           1
# 4662            Little Big Top          10.0           1
# 3992                 Sardaarji           9.5           2
# 2386            One Man's Hero           9.3           2
# 2970        There Goes My Baby           8.5           2
# 1881  The Shawshank Redemption           8.5        8205
# 2796     The Prisoner of Zenda           8.4          11
# 3337             The Godfather           8.4        5893

# %% [markdown]
# ## 가중평점(평점&평가횟수) 반영한 영화 추천

# %% [raw]
# @ 가중평점(Weighted Rating):
#
#    (v/(v+m))*R + (m/(v+m))*C
#
# - v : 영화별 평점을 투표한 횟수(vote_count) ★ 투표횟수가 많은 영화에 가중치 부여
# - m : 평점을 부여하기 위한 최소 투표 횟수 -> 여기서는 투표수 상위 60%
# - R : 개별 영화에 대한 평균 평점(vote_average)
# - C : 전체 영화에 대한 평균 평점(movies_df['vote_average'].mean()
# - C, m은 영화마다 고정값
# - v, R은 영화마다 변동값

# %%
# 상위 60%에 해당하는 vote_count를 최소 투표 횟수인 m으로 지정
C = movies_df['vote_average'].mean()
m = movies_df['vote_count'].quantile(0.6)

# %%
# C: 전체 영화에 대한 평균평점 = 약 6점
# m: 평점을 부여하기 위한 최소 투표 횟수 = 370회(상위 60% 수준)
print('C:', round(C,3), 'm:', round(m,3))
# Out:
# C: 6.092 m: 370.2

# %% [markdown]
# ### 가중평점을 계산하는 함수

# %%
def weighted_vote_average(record):
    v = record['vote_count']
    R = record['vote_average']
    
    return ( (v/(v+m)) * R ) + ( (m/(m+v)) * C )     # 가중평점 반환

# %%
# 기존 데이터에 가중평점 칼럼 추가
movies_df['weighted_vote'] = movies_df.apply(weighted_vote_average, axis=1)

# %%
movies_df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                              genres  vote_average  vote_count  \
# 0     [Action, Adventure, Fantasy, Science Fiction]           7.2       11800
# 1                      [Adventure, Fantasy, Action]           6.9        4500
# ...

# %%
# 가중평점(weighted_vote) 기준으로 영화 순위 뽑아보기
movies_df[['weighted_vote','title','vote_average','vote_count','genres']].sort_values(
    'weighted_vote', ascending=False)[:10]
# Out:
#       weighted_vote                     title  vote_average  vote_count  \
# 1881       8.396052  The Shawshank Redemption           8.5        8205
# 3337       8.263591             The Godfather           8.4        5893
# 662        8.216455                Fight Club           8.3        9413
# 3232       8.207102              Pulp Fiction           8.3        8428
# 65         8.136930           The Dark Knight           8.2       12002
# 1818       8.126069          Schindler's List           8.3        4329
# 3865       8.123248                  Whiplash           8.3        4254
# 809        8.105954              Forrest Gump           8.2        7927
# 2294       8.105867             Spirited Away           8.3        3840
# 2731       8.079586    The Godfather: Part II           8.3        3338
#
#                                        genres
# 1881                           [Drama, Crime]
# 3337                           [Drama, Crime]
# ...

# %% [markdown]
# ## 추천 ver2. 먼저 장르 유사성 높은 영화 20개 선정 후(F1), 가중평점순 10개 선정(F2)

# %%
def find_sim_movie_ver2(df, sorted_ind, title_name, top_n=10):
    title_movie = df[df['title'] == title_name]
    title_index = title_movie.index.values
    
    # top_n의 2배에 해당하는 쟝르 유사성이 높은 index 추출
    similar_indexes = sorted_ind[title_index, :(top_n*2)]
    similar_indexes = similar_indexes.reshape(-1)

    # 기준 영화 index는 제외
    similar_indexes = similar_indexes[similar_indexes != title_index]
    
    # top_n의 2배에 해당하는 후보군에서 weighted_vote 높은 순으로 top_n 만큼 추출
    return df.iloc[similar_indexes].sort_values('weighted_vote', ascending=False)[:top_n]

# %% [raw]
# 흐름
# 1. 장르 코사인 유사도 -> 평점 x, 투표수 x
# 2. 가중평점 -> 투표수, 영화 평점, 장르

# %% [markdown]
# ### 영화 Gotfather에 대해 장르 유사성, 가중평점 반영한 추천 영화 10개를 뽑아보자

# %%
movies_df
# Out:
#           id                                     title  \
# 0      19995                                    Avatar
# 1        285  Pirates of the Caribbean: At World's End
# 2     206647                                   Spectre
# 3      49026                     The Dark Knight Rises
# 4      49529                               John Carter
# ...      ...                                       ...
# 4798    9367                               El Mariachi
# 4799   72766                                 Newlyweds
# 4800  231617                 Signed, Sealed, Delivered
# 4801  126186                          Shanghai Calling
# 4802   25975                         My Date with Drew
#
#                                              genres  vote_average  vote_count  \
# 0     [Action, Adventure, Fantasy, Science Fiction]           7.2       11800
# 1                      [Adventure, Fantasy, Action]           6.9        4500
# ...

# %%
genre_sim_sorted_ind
# Out:
# array([[   0, 3494,  813, ..., 3038, 3037, 2401],
#        [ 262,    1,  129, ..., 3069, 3067, 2401],
#        [   2, 1740, 1542, ..., 3000, 2999, 2401],
#        ...,
#        [4800, 3809, 1895, ..., 2229, 2230,    0],
#        [4802, 1594, 1596, ..., 3204, 3205,    0],
#        [4802, 4710, 4521, ..., 3140, 3141,    0]])

# %%
similar_movies = find_sim_movie_ver2(movies_df, genre_sim_sorted_ind, 'Catch Me If You Can', 10)
similar_movies[['title', 'vote_average', 'weighted_vote', 'genres', 'vote_count']]
# Out:
#                             title  vote_average  weighted_vote  \
# 3337                The Godfather           8.4       8.263591
# 2731       The Godfather: Part II           8.3       8.079586
# 1847                   GoodFellas           8.2       7.976937
# 3866                  City of God           8.1       7.759693
# 1663  Once Upon a Time in America           8.2       7.657811
# 281             American Gangster           7.4       7.141396
# 4041              This Is England           7.4       6.739664
# 1149              American Hustle           6.8       6.717525
# 1243                 Mean Streets           7.2       6.626569
# 2839                     Rounders           6.9       6.530427
#
#               genres  vote_count
# 3337  [Drama, Crime]        5893
# 2731  [Drama, Crime]        3338
# 1847  [Drama, Crime]        3128
# 3866  [Drama, Crime]        1814
# 1663  [Drama, Crime]        1069
# 281   [Drama, Crime]        1502
# 4041  [Drama, Crime]         363
# ...

# %% [markdown]
# ## 요약 : Gotfather를 좋아하는 사람에게 영화 추천해주기

# %% [raw]
# 'Catch Me If You Can' 장르가 Drama, Crime이다.
# 1. 우선 Drama, Crime 장르 기준으로 상위 20개(top_n=10 * 2) 영화를 뽑아보고,
# 2. 그 중 평가횟수를 반영한 가중평점 기준 상위 10개 영화를 뽑아서 추천해준다.

# %% [markdown]
# ### 응용 : Warcraft 좋아하는 사람 기준으로 장르가 유사한 영화를 추천해주자

# %%
similar_movies = find_sim_movie_ver2(movies_df, genre_sim_sorted_ind, 'Warcraft',10)
similar_movies[['title', 'vote_average', 'weighted_vote', 'genres', 'vote_count']]
# Out:
#                                                  title  vote_average  \
# 329      The Lord of the Rings: The Return of the King           8.1
# 262  The Lord of the Rings: The Fellowship of the Ring           8.0
# 199  Pirates of the Caribbean: The Curse of the Bla...           7.5
# 19           The Hobbit: The Battle of the Five Armies           7.1
# 126                               Thor: The Dark World           6.8
# 30                                        Spider-Man 2           6.7
# 20                              The Amazing Spider-Man           6.5
# 38                            The Amazing Spider-Man 2           6.5
# 208                                   The 13th Warrior           6.4
# 836                              The Forbidden Kingdom           6.3
#
#      weighted_vote                        genres  vote_count
# 329       8.011871  [Adventure, Fantasy, Action]        8064
# 262       7.922175  [Adventure, Fantasy, Action]        8705
# ...

# %% [markdown]
# ### 응용 : Enemy at the Gates 좋아하는 사람 기준으로 장르가 유사한 영화를 추천해주자

# %%
similar_movies = find_sim_movie_ver2(movies_df, genre_sim_sorted_ind, 'Enemy at the Gates',10)
similar_movies[['title', 'vote_average', 'weighted_vote', 'genres', 'vote_count']]
# Out:
#                                title  vote_average  weighted_vote  \
# 1525                  Apocalypse Now           8.0       7.708775
# 2798  The Boy in the Striped Pyjamas           7.7       7.373173
# 2536                 The Deer Hunter           7.8       7.310348
# 1662                           Glory           7.4       6.757199
# 585                        War Horse           7.0       6.753283
# 2662                     Sarah's Key           7.2       6.475666
# 2016               The Water Diviner           6.8       6.472943
# 557                          Jarhead           6.6       6.434392
# 2671      Born on the Fourth of July           6.7       6.405936
# 3310                    Far from Men           6.6       6.145019
#
#             genres  vote_count
# 1525  [Drama, War]        2055
# 2798  [War, Drama]        1451
# 2536  [Drama, War]         921
# 1662         [War]         383
# 585   [Drama, War]         992
# 2662  [Drama, War]         196
# ...

# %% [raw]
# 영화 - 장르를 자연어처리해서 코사인 유사도 계산
# 화장품 - 키워드
#
# contents based filtering
# <cbf 기반의 추천시스템 응용>
# 화장품 : 보습, 민감성 피부용, 건성용, ...
# 노래 : 발라드, 락, 멜로, 사랑, 이별,
# 와인 :
# 맥주 :

# %% [raw]
# 1. cbf
#
# 2. cf
#    - knn
#    - mf
