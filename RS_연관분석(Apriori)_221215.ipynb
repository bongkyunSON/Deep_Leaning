# %% [markdown]
# <a href="https://colab.research.google.com/github/bongkyunSON/Deep_Leaning/blob/main/RS_%EC%97%B0%EA%B4%80%EB%B6%84%EC%84%9D(Apriori)_221215.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [raw]
# 다음과 같은 5개 item에 대한 4건의 거래 데이터가 있다면

# %%
data = np.array([
    ['우유', '기저귀', '주스'],
    ['양상추', '기저귀', '맥주'],
    ['우유', '양상추', '기저귀', '맥주'],
    ['양상추', '맥주']
])

data
# Out:
# <ipython-input-2-4d39e8bb5946>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data = np.array([
# array([list(['우유', '기저귀', '주스']), list(['양상추', '기저귀', '맥주']),
#        list(['우유', '양상추', '기저귀', '맥주']), list(['양상추', '맥주'])],
#       dtype=object)

# %% [markdown]
# ### matrix로 변환

# %%
from mlxtend.preprocessing import TransactionEncoder
te = TransactionEncoder()
# Sparce matrix로 변형
te_ary = te.fit(data).transform(data)
te_ary
# Out:
# array([[ True, False, False,  True,  True],
#        [ True,  True,  True, False, False],
#        [ True,  True,  True,  True, False],
#        [False,  True,  True, False, False]])

# %%
# column명 확인
te.columns_
# Out:
# ['기저귀', '맥주', '양상추', '우유', '주스']

# %%
# 데이터프레임으로 변환
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#      기저귀     맥주    양상추     우유     주스
# 0   True  False  False   True   True
# 1   True   True   True  False  False
# 2   True   True   True   True  False
# 3  False   True   True  False  False

# %% [markdown]
# ### apriori 적용

# %%
from mlxtend.frequent_patterns import apriori

# 지지도가 0.5 이상인 item sets만 보기
frequent_itemsets = apriori(df, min_support=0.5, use_colnames=True)
frequent_itemsets
# Out:
#    support        itemsets
# 0     0.75           (기저귀)
# 1     0.75            (맥주)
# 2     0.75           (양상추)
# 3     0.50            (우유)
# 4     0.50       (맥주, 기저귀)
# 5     0.50      (기저귀, 양상추)
# 6     0.50       (우유, 기저귀)
# 7     0.75       (맥주, 양상추)
# 8     0.50  (맥주, 기저귀, 양상추)

# %% [markdown]
# ### 연관규칙 확인

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets, metric="support", min_threshold=0.05)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (맥주)       (기저귀)                0.75                0.75     0.50
# 1        (기저귀)        (맥주)                0.75                0.75     0.50
# 2        (기저귀)       (양상추)                0.75                0.75     0.50
# 3        (양상추)       (기저귀)                0.75                0.75     0.50
# 4         (우유)       (기저귀)                0.50                0.75     0.50
# 5        (기저귀)        (우유)                0.75                0.50     0.50
# 6         (맥주)       (양상추)                0.75                0.75     0.75
# 7        (양상추)        (맥주)                0.75                0.75     0.75
# 8    (맥주, 기저귀)       (양상추)                0.50                0.75     0.50
# 9    (맥주, 양상추)       (기저귀)                0.75                0.75     0.50
# 10  (기저귀, 양상추)        (맥주)                0.50                0.75     0.50
# ...
